# %% [markdown]
# ## Skin color classification

# %%
train_data_directory = 'dataset/train/skin'
test_data_directory = 'dataset/test/skin'

import cv2 # open cv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

load_model = tf.keras.models.load_model
image = tf.keras.preprocessing.image
ImageDataGenerator = tf.keras.preprocessing.image.ImageDataGenerator
Sequential = tf.keras.models.Sequential
Dense = tf.keras.layers.Dense
Activation = tf.keras.layers.Activation
Flatten = tf.keras.layers.Flatten
Conv2D = tf.keras.layers.Conv2D
MaxPooling2D = tf.keras.layers.MaxPooling2D

picture_width = 400
picture_height = 540

CLASSES = ['black','brown','white']
MODEL_NAME = 'skin'

# %%
# initiate data preprocessing tools

# This step processes the images into a format that
# 1. makes the data readable to the model
# 2. provides more training material for the model to train from
# the `training_data_processor` below scales the data so that it can be
# a model input, but also takes each image and augments it so that
# the model can learn from multiple variations of the same image.
# it flips it horizontally, rotates it, shifts it, and more so that 
# the model learns from the soil photo rather than the orientation size
training_data_processor  = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    zoom_range = 0.2,
    rotation_range = 10,
    shear_range = 0.2,
    height_shift_range = 0.1,
    width_shift_range = 0.1,
)
# for the testing images, we don't need to create multiple variatinos
test_data_processor = ImageDataGenerator(rescale=1./255)


# load data into python

training_data = training_data_processor.flow_from_directory(
    train_data_directory,
    target_size = (picture_width, picture_height), # pixels
    batch_size = 32,
    class_mode = 'categorical',
)

testing_data = test_data_processor.flow_from_directory(
    test_data_directory,
    target_size = (picture_width, picture_height),
    batch_size = 32,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 98 images belonging to 3 classes.
# Found 28 images belonging to 3 classes.

# %%
# choose model parameters
num_conv_layers = 3
num_dense_layers = 2
layer_size = 29 # limit the layer size as we dont want to over fit the model
num_training_epochs = 25

model = Sequential()

# begin adding properties to model variable
# e.g. add a convulutional layer
model.add(Conv2D(layer_size, (3,3), input_shape=(picture_width, picture_height, 3)))
model.add(Activation('relu')) # rectified linear unit
model.add(MaxPooling2D(pool_size=(2,2)))

# add additional convolutional layers based on num_conv_layers
for _ in range(num_conv_layers-1):
    model.add(Conv2D(layer_size, (3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

# reduce dimensionality
model.add(Flatten())

# add fully connected "dense" layers if specified
for _ in range(num_dense_layers):
    model.add(Dense(layer_size))
    model.add(Activation('relu'))

# output layer
model.add(Dense(len(CLASSES)))
model.add(Activation('softmax'))

# compile the sequential model with all added properties
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# use the data already loaded to train/tune the model
model.fit(
    training_data, 
    epochs = num_training_epochs, 
    validation_data = testing_data)

# save the trained model
model.save(f'h5_models/{MODEL_NAME}.h5')
# Out:
# Epoch 1/25
# 4/4 [==============================] - 13s 4s/step - loss: 2.1136 - accuracy: 0.3673 - val_loss: 1.3469 - val_accuracy: 0.3214
# Epoch 2/25
# 4/4 [==============================] - 14s 3s/step - loss: 1.0600 - accuracy: 0.3265 - val_loss: 1.0484 - val_accuracy: 0.3214
# Epoch 3/25
# 4/4 [==============================] - 14s 3s/step - loss: 0.9538 - accuracy: 0.4490 - val_loss: 1.0963 - val_accuracy: 0.3214
# Epoch 4/25
# 4/4 [==============================] - 13s 4s/step - loss: 0.9933 - accuracy: 0.4796 - val_loss: 0.9107 - val_accuracy: 0.6429
# Epoch 5/25
# 4/4 [==============================] - 13s 4s/step - loss: 1.0796 - accuracy: 0.5000 - val_loss: 1.0869 - val_accuracy: 0.3214
# Epoch 6/25
# 4/4 [==============================] - 13s 3s/step - loss: 1.0698 - accuracy: 0.3980 - val_loss: 1.0388 - val_accuracy: 0.5000
# Epoch 7/25
# 4/4 [==============================] - 12s 4s/step - loss: 1.0270 - accuracy: 0.4490 - val_loss: 1.0552 - val_accuracy: 0.3214
# Epoch 8/25
# 4/4 [==============================] - 14s 3s/step - loss: 1.0134 - accuracy: 0.4490 - val_loss: 1.1113 - val_accuracy: 0.3214
# Epoch 9/25
# 4/4 [==============================] - 13s 3s/step - loss: 1.0277 - accuracy: 0.4490 - val_loss: 1.0561 - val_accuracy: 0.3214
# Epoch 10/25
# 4/4 [==============================] - 12s 4s/step - loss: 0.9521 - accuracy: 0.4490 - val_loss: 0.9884 - val_accuracy: 0.3214
# Epoch 11/25
# 4/4 [==============================] - 12s 4s/step - loss: 0.9305 - accuracy: 0.4490 - val_loss: 0.9974 - val_accuracy: 0.3214
# Epoch 12/25
# 4/4 [==============================] - 12s 3s/step - loss: 0.8629 - accuracy: 0.4490 - val_loss: 0.9454 - val_accuracy: 0.5714
# Epoch 13/25
# 4/4 [==============================] - 12s 3s/step - loss: 0.8242 - accuracy: 0.6020 - val_loss: 0.9263 - val_accuracy: 0.6071
# Epoch 14/25
# 4/4 [==============================] - 13s 4s/step - loss: 0.7899 - accuracy: 0.6735 - val_loss: 0.9724 - val_accuracy: 0.6071
# Epoch 15/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.8072 - accuracy: 0.6633 - val_loss: 0.9273 - val_accuracy: 0.6786
# Epoch 16/25
# 4/4 [==============================] - 12s 4s/step - loss: 0.8073 - accuracy: 0.6531 - val_loss: 0.8444 - val_accuracy: 0.6786
# Epoch 17/25
# 4/4 [==============================] - 12s 3s/step - loss: 0.8179 - accuracy: 0.6837 - val_loss: 0.8332 - val_accuracy: 0.6786
# Epoch 18/25
# 4/4 [==============================] - 12s 4s/step - loss: 0.8346 - accuracy: 0.6122 - val_loss: 0.8608 - val_accuracy: 0.6071
# Epoch 19/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.7847 - accuracy: 0.6429 - val_loss: 0.8343 - val_accuracy: 0.6786
# Epoch 20/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.8589 - accuracy: 0.6224 - val_loss: 0.8061 - val_accuracy: 0.5714
# Epoch 21/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.7263 - accuracy: 0.6735 - val_loss: 0.8666 - val_accuracy: 0.7143
# Epoch 22/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.6835 - accuracy: 0.6837 - val_loss: 0.7087 - val_accuracy: 0.7857
# Epoch 23/25
# 4/4 [==============================] - 12s 3s/step - loss: 0.6782 - accuracy: 0.7653 - val_loss: 0.6999 - val_accuracy: 0.6429
# Epoch 24/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.6528 - accuracy: 0.7449 - val_loss: 0.6792 - val_accuracy: 0.6429
# Epoch 25/25
# 4/4 [==============================] - 12s 3s/step - loss: 0.6214 - accuracy: 0.7347 - val_loss: 0.6948 - val_accuracy: 0.7857

# %%
model.evaluate(training_data)
# Out:
# 4/4 [==============================] - 5s 953ms/step - loss: 0.6469 - accuracy: 0.7143
# [0.646906316280365, 0.7142857313156128]

# %%
def classify(image_fp):
    im = cv2.imread(image_fp) # load the image from the given file path (image_fp)
    plt.imshow(im[:,:,[2,1,0]]) # swap the colors because open-cv swaps the rgb colors
    img = image.load_img(image_fp, target_size = (picture_width, picture_height))
    img = image.img_to_array(img)

    image_array = img / 255. # scale the image
    img_batch = np.expand_dims(image_array, axis = 0)

    from tensorflow import keras
    model = keras.models.load_model(f'h5_models/{MODEL_NAME}.h5')
    predicted_value = model.predict(img_batch)

    # accuracy = model.evaluate(training_data)
    
    out  = f"""
     black: {predicted_value[0][0]:.5f}
      brown: {predicted_value[0][1]:.5f}
     white: {predicted_value[0][2]:.5f}

    Confidence: {(predicted_value[0][predicted_value.argmax()] * 100):.2f}%
    Eye color: {CLASSES[predicted_value.argmax()]}

    """
  # accuracy: {(accuracy[1]*100):.5f}
  #     loss: {(accuracy[0]*100):.5f}
    return out


test_prediction = classify('dataset/test/skin/black/9234d89bdb2da9f16f5e2a7b843c08ca--three-kids.jpg')
# test_prediction = classify('dataset/test/skin/brown/3384364943_5446d4ddf7 (2).jpg')
# test_prediction = classify('dataset/test/skin/white/3-to-5-header.jpg')
print(test_prediction)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002E180184430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#      black: 0.32340
#       brown: 0.47915
#      white: 0.19745
#
#     Confidence: 47.92%
#     Eye color: brown
